# %% [markdown]
# ## [作業目標]
# 了解機器學習適合應用的領域與範疇。

# %% [markdown]
# ## [作業重點]
# 透過瞭解機器學習的運作方式，找出非常適用機器學習應用的領域及其原因

# %% [markdown]
# ## 作業
# 請找出一個你認為機器學習可以發光發熱的領域並闡述原因?
#     Ans: "透過機械學習, 雖然一開始成本高, 但當技術純熟系統完整時, 可以省去相當多的人力, 在任何產業上人為失誤是最常見的, 所以當機械學習去取代人為的行為誤差一定也會減少, 損失也會相對較少"
