# %% [markdown]
# ## 練習時間
# 資料的操作有很多，接下來的馬拉松中我們會介紹常被使用到的操作，參加者不妨先自行想像一下，第一次看到資料，我們一般會想知道什麼訊息？
#
# #### Ex: 如何知道資料的 row 數以及 column 數、有什麼欄位、多少欄位、如何截取部分的資料等等
#
# 有了對資料的好奇之後，我們又怎麼通過程式碼來達成我們的目的呢？
#
# #### 可參考該[基礎教材](https://bookdata.readthedocs.io/en/latest/base/01_pandas.html#DataFrame-%E5%85%A5%E9%97%A8)或自行 google

# %% [markdown]
# # [作業目標]
# - 熟悉更多的 Python 資料操作

# %% [markdown]
# # [作業重點]
# - 列出資料的大小 (In[4], Hint : shape)
# - 列出所有欄位 (In[5], 有多種寫法)
# - 擷取部分資料 (In[6], Hint : loc 或 iloc)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import os
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
# 設定 data_path
dir_data = 'C:/Users/YUN.CHEN/Desktop/Github/3rd-ML100Days/homework/example/day004 data/'

# %%
f_app = os.path.join(dir_data, 'application_train.csv')
print('Path of read in data: %s' % (f_app))
app_train = pd.read_csv(f_app)
# Out:
# Path of read in data: C:/Users/YUN.CHEN/Desktop/Github/3rd-ML100Days/homework/example/day004 data/application_train.csv

# %% [markdown]
# ### 如果沒有想法，可以先嘗試找出剛剛例子中提到的問題的答案
# #### 資料的 row 數以及 column 數

# %%
print ('column:',app_train.shape[1])
print('row:',app_train.shape[0])
# Out:
# column: 122
# row: 307511

# %% [markdown]
# #### 列出所有欄位

# %%
print (app_train.columns)
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER',
#        'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL',
#        'AMT_CREDIT', 'AMT_ANNUITY',
#        ...
#        'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20',
#        'FLAG_DOCUMENT_21', 'AMT_REQ_CREDIT_BUREAU_HOUR',
#        'AMT_REQ_CREDIT_BUREAU_DAY', 'AMT_REQ_CREDIT_BUREAU_WEEK',
#        'AMT_REQ_CREDIT_BUREAU_MON', 'AMT_REQ_CREDIT_BUREAU_QRT',
#        'AMT_REQ_CREDIT_BUREAU_YEAR'],
#       dtype='object', length=122)

# %% [markdown]
# #### 截取部分資料

# %%
print (app_train['SK_ID_CURR'])
print(type(app_train['SK_ID_CURR']))
# Out:
# 0         100002
# 1         100003
# 2         100004
# 3         100006
# 4         100007
# 5         100008
# 6         100009
# 7         100010
# 8         100011
# 9         100012
# 10        100014
# 11        100015
# 12        100016
# 13        100017
# 14        100018
# 15        100019
# 16        100020
# 17        100021
# 18        100022
# 19        100023
# 20        100024
# 21        100025
# 22        100026
# 23        100027
# 24        100029
# 25        100030
# 26        100031
# 27        100032
# 28        100033
# 29        100034
#            ...
# 307481    456225
# 307482    456226
# 307483    456227
# 307484    456228
# 307485    456229
# 307486    456230
# 307487    456231
# 307488    456232
# 307489    456233
# 307490    456234
# 307491    456235
# 307492    456236
# 307493    456237
# 307494    456238
# 307495    456239
# 307496    456240
# 307497    456241
# 307498    456242
# 307499    456243
# 307500    456244
# 307501    456245
# 307502    456246
# 307503    456247
# 307504    456248
# 307505    456249
# 307506    456251
# 307507    456252
# 307508    456253
# 307509    456254
# 307510    456255
# Name: SK_ID_CURR, Length: 307511, dtype: int64
# <class 'pandas.core.series.Series'>

# %%
app_train[2:4]
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 2               Y             0           67500.0    135000.0       6750.0
# 3               Y             0          135000.0    312682.5      29686.5
#
#               ...              FLAG_DOCUMENT_18 FLAG_DOCUMENT_19  \
# 2             ...                             0                0
# 3             ...                             0                0
#
#   FLAG_DOCUMENT_20 FLAG_DOCUMENT_21 AMT_REQ_CREDIT_BUREAU_HOUR  \
# 2                0                0                        0.0
# 3                0                0                        NaN
#
#   AMT_REQ_CREDIT_BUREAU_DAY  AMT_REQ_CREDIT_BUREAU_WEEK  \
# 2                       0.0                         0.0
# 3                       NaN                         NaN
#
#    AMT_REQ_CREDIT_BUREAU_MON  AMT_REQ_CREDIT_BUREAU_QRT  \
# 2                        0.0                        0.0
# 3                        NaN                        NaN
#
#    AMT_REQ_CREDIT_BUREAU_YEAR
# 2                         0.0
# 3                         NaN
#
# [2 rows x 122 columns]

# %% [markdown]
# #### 還有各種數之不盡的資料操作，重點還是取決於實務中遇到的狀況和你想問的問題，在馬拉松中我們也會陸續提到更多例子
